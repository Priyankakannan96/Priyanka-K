# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyankakannan96/Priyanka-K/blob/main/Statistics_Module_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a id='1'></a><center> <h3 style="background-color:orange; color:white" ><br>Telecommunication Industry Project<br></h3>

# %% [markdown]
# # Introduction
# This Jupyter notebook is part of your learning experience in the study of applied statistics.
#
# You will work with a data set that contains mobile phone prices and their specifications.
#
# **Dataset Columns Information**
#
# PID = a unique identifier for the phone model
#
# Blue = whether the phone has bluetooth support or not
#
# Wi_Fi = whether the phone has wifi support or not
#
# Tch_Scr = whether the phone has touch screen support or not
#
# Ext_Mem = whether the phone has external memory support or not
#
# Px_h = number of pixels in the vertical axis of the phone
#
# Px_w = number of pixels in the horizontal axis of the phone
#
# Scr_h = height of the screen of the phone in centimetres (cm)
#
# Scr_w = width of the screen of the phone in centimetres (cm)
#
# Int_Mem = internal memory of the phone measured in megabytes (MB)
#
# Bty_Pwr = maximum energy stored by the phone's battery measured in
# milli-Ampere-hours (mAh)
#
# PC = resolution of the primary camera measued in megapixels (MP)
#
# FC = resolution of the front camera measued in megapixels (MP)
#
# RAM = random access memory available in the phone measured in gigabytes (GB)
#
# Depth = depth of the mobile phone measured in centimetres (cm)
#
# Weight = weight of the mobile phone measured in grams (g)
#
# Price = selling price of the mobile phone in rupees

# %% [markdown]
# ## Task 1 - Load and study the data

# %% [markdown]
# Import the libraries that will be used in this notebook

# %%
# Load "numpy" and "pandas" for manipulating numbers and data frames
# Load "matplotlib.pyplot" and "seaborn" for data visualisation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the csv file as pandas dataframe.

# %%
# Read in the "Dataset" file as a Pandas Data Frame
data=pd.read_csv('/content/Telecom Dataset.csv')

# %%
# Take a brief look at the data
data.head()
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price
# 0        8     2800    2      7     320   3297
# 1        8     3000    2      7     280   4500
# 2        8     3300    2      7     400   4898
# 3       32     3000    2      3     300   6900
# 4       16     3000    2      3     210   5600

# %%
# Get the dimensions of the dataframe
data.shape
# Out:
# (50, 17)

# %%
# Get the row names of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# Get the column names of the dataframe
import pandas as pd
data.columns
# Out:
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price'],
#       dtype='object')

# %%
# Look at basic information about the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PID      50 non-null     object
#  1   Blue     50 non-null     object
#  2   Wi_Fi    50 non-null     object
#  3   Tch_Scr  50 non-null     object
#  4   Ext_Mem  50 non-null     object
#  5   Px_h     50 non-null     int64
#  6   Px_w     50 non-null     int64
#  7   Scr_h    50 non-null     int64
#  8   Scr_w    50 non-null     int64
#  9   PC       50 non-null     int64
#  10  FC       50 non-null     int64
#  11  Int_Mem  50 non-null     int64
#  12  Bty_Pwr  50 non-null     int64
#  13  RAM      50 non-null     int64
#  14  Depth    50 non-null     int64
#  15  Weight   50 non-null     int64
#  16  Price    50 non-null     int64
# dtypes: int64(12), object(5)
# memory usage: 6.8+ KB

# %% [markdown]
# Observations:
#
# There are 50 phones in the data set.
#
# There are 17 features in the data set including the "PID" feature which is used as the row index labels.
#
# There are no missing values in the data set.

# %% [markdown]
# <center>Let's try some logical operators to filter the data.<center>

# %% [markdown]
# ![](https://th.bing.com/th/id/R.0592084daa6518e4fae97f47217ec69e?rik=vNqmiaTVSSo54w&riu=http%3a%2f%2f2.bp.blogspot.com%2f-ujABms6N-Cg%2fTyYwShdTjnI%2fAAAAAAAAAAs%2fktPbHdifidc%2fs1600%2fLogical%2bOperators.PNG&ehk=ww1gl1HB2PcZwPQNHWRUvcQ631Q3mzyHSxL9G4zUKT4%3d&risl=&pid=ImgRaw&r=0,width=700,height=400)

# %% [markdown]
# ## Task 2 - Obtain the logical conditions for the features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem"

# %%
# Get the feature names of the dataframe
data.head()
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price
# 0        8     2800    2      7     320   3297
# 1        8     3000    2      7     280   4500
# 2        8     3300    2      7     400   4898
# 3       32     3000    2      3     300   6900
# 4       16     3000    2      3     210   5600

# %%
specific_rows = ['Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem']
print(specific_rows)
# Out:
# ['Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem']

# %%
# Logical conditions for the given features
blue_condition = data['Blue'] == True  # Adjust value based on your criteria
wifi_condition = data['Wi_Fi'] == True  # Adjust value based on your criteria
tch_scr_condition = data['Tch_Scr'] == True  # Adjust value based on your criteria
ext_mem_condition = data['Ext_Mem'] == True  # Adjust value based on your criteria

# Combine conditions using logical AND (&) or OR (|)
combined_condition = blue_condition & wifi_condition & tch_scr_condition & ext_mem_condition

# Apply the condition to the DataFrame
filtered_data = data[combined_condition]

print(filtered_data)
# Out:
# Empty DataFrame
# Columns: [PID, Blue, Wi_Fi, Tch_Scr, Ext_Mem, Px_h, Px_w, Scr_h, Scr_w, PC, FC, Int_Mem, Bty_Pwr, RAM, Depth, Weight, Price]
# Index: []

# %%
# Let's tackle these features: "Blue", "Wi_Fi", "Tch_Scr", "Ext_Mem"
# Check unique values for the features
print("Unique values in 'Blue':", data['Blue'].unique())
print("Unique values in 'Wi_Fi':", data['Wi_Fi'].unique())
print("Unique values in 'Tch_Scr':", data['Tch_Scr'].unique())
print("Unique values in 'Ext_Mem':", data['Ext_Mem'].unique())
# Out:
# Unique values in 'Blue': ['yes' 'no']
# Unique values in 'Wi_Fi': ['yes' 'no']
# Unique values in 'Tch_Scr': ['no' 'yes']
# Unique values in 'Ext_Mem': ['no' 'yes']

# %%
# The children want phones that have the following: Bluetooth, WiFi, touch screen and external memory support
# Create a logical condition for this situation and store the logical values as "con1"
con1 = {
    'Bluetooth': True,
    'WiFi': True,
    'TouchScreen': True,
    'ExternalMemorySupport': True
}

# %% [markdown]
# Observations:
#
# The features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem" are binary in nature.
#
# The children want all these features, so the logical condition "con1" has been obtained accordingly.

# %% [markdown]
# ## Task 3 - Obtain the logical conditions for the features "Px_h" and "Px_w"

# %%
# Get the feature names of the dataframe
number_of_pixels_in_the_vertical_axis_of_the_phone = data['Px_h'] == True  # Adjust value based on your criteria
number_of_pixels_in_the_horizontal_axis_of_the_phone = data['Px_w'] == True  # Adjust value based on your criteria

# Combine conditions using logical AND (&) or OR (|)
combined_condition = number_of_pixels_in_the_vertical_axis_of_the_phone | number_of_pixels_in_the_horizontal_axis_of_the_phone

# Apply the condition to the DataFrame
filtered_data = data[combined_condition]

print(filtered_data)
# Out:
# Empty DataFrame
# Columns: [PID, Blue, Wi_Fi, Tch_Scr, Ext_Mem, Px_h, Px_w, Scr_h, Scr_w, PC, FC, Int_Mem, Bty_Pwr, RAM, Depth, Weight, Price]
# Index: []

# %%
# Let's tackle these features: "Px_h", "Px_w"

# %%
# Create a new feature called "Px" which stores the total resolution of the screen

data['Px'] = data['Px_h'] * data['Px_w']
print(data['Px'])
# Out:
# 0      358800
# 1      436800
# 2      604800
# 3     1433600
# 4     1382400
# 5     1382400
# 6     1501200
# 7     6105600
# 8     4953600
# 9     5108400
# 10    4953600
# 11    4953600
# 12    5108400
# 13    6105600
# 14    4331600
# 15    3484800
# 16    5108400
# 17    6105600
# 18    3484800
# 19    6105600
# 20    3484800
# 21    5108400
# 22    1843200
# 23    6105600
# 24    1843200
# 25    5108400
# 26    2534400
# 27    5469600
# 28    5469600
# 29    5469600
# 30    5469600
# 31    5469600
# 32    5469600
# 33    5469600
# 34    6105600
# 35    5172800
# 36    5108400
# 37    4831200
# 38    4953600
# 39    4831200
# 40    5108400
# 41    5108400
# 42    5108400
# 43    5108400
# 44    5108400
# 45    5108400
# 46    5108400
# 47    7257600
# 48    7257600
# 49    7257600
# Name: Px, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the mean and median of the 'PX' feature
mean_Px = data['Px'].mean()
median_Px = data['Px'].median()

# Create the histogram of 'Px'
plt.figure(figsize=(10, 6))
sns.histplot(data['Px'], bins=30, kde=True, color='darkgreen', label='Px')

# Add vertical lines for the mean and median
plt.axvline(mean_Px, color='red', linestyle='--', label=f'Mean: {mean_Px:.2f}')
plt.axvline(median_Px, color='black', linestyle='--', label=f'Median: {median_Px:.2f}')

# Adding titles and labels
plt.title('Histogram of the Px Feature', fontsize=16)
plt.xlabel('Px', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# The children want phones that have good screen resolutions
# Consider the phones that have screen resolutions greater than or equal to the median value in the data set
# Create a logical condition for this situation and store the logical values as "con2"

# Calculate the median of the "Px" feature
median_px = data['Px'].median()

# Create the logical condition for phones with resolution >= median
data['con2'] = data['Px'] >= median_px

# Display the first few rows to confirm the new column
print(data[['Px', 'con2']].head())
# Out:
#         Px   con2
# 0   358800  False
# 1   436800  False
# 2   604800  False
# 3  1433600  False
# 4  1382400  False

# %% [markdown]
# Observations:
#
# The features "Px_h" and "Px_w" are respectively the number of pixels in the phone screen in the vertical and horizontal axes.
#
# We created a new feature called "Px" which is the product of the features "Px_h" and "Px_w".
#
# The median has been selected as a threshold in this case.
#
# In case it is too strict, we can choose the mean as a threshold.

# %% [markdown]
# # Task 4 - Obtain the logical conditions for the features "Scr_h" and "Scr_w"

# %%
# Let's tackle these features: "Scr_h", "Scr_w"

# %%
# Create a new feature called "Scr_d" which stores the length of the diagonal of the screen of the phone
data['Scr_d'] = data['Scr_h'] * data['Scr_w']
print(data['Scr_d'])
# Out:
# 0      3
# 1      2
# 2      2
# 3     15
# 4     12
# 5     12
# 6     18
# 7     48
# 8     18
# 9     15
# 10    18
# 11    48
# 12    30
# 13    30
# 14    15
# 15    80
# 16    48
# 17    48
# 18    48
# 19    12
# 20    12
# 21    48
# 22    12
# 23    80
# 24    24
# 25    18
# 26    15
# 27    48
# 28    48
# 29    48
# 30    48
# 31    48
# 32    48
# 33    48
# 34    18
# 35    15
# 36    80
# 37    15
# 38    15
# 39    30
# 40    15
# 41    48
# 42    48
# 43    48
# 44    80
# 45    48
# 46    12
# 47    48
# 48    48
# 49    48
# Name: Scr_d, dtype: int64

# %%
# Create a histogram of the "Scr_d" feature and also show the quartiles
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the quartiles of the 'Scr_d' feature
q1 = data['Scr_d'].quantile(0.25)  # 1st quartile (25th percentile)
median_scr_d = data['Scr_d'].median()  # Median (50th percentile)
q3 = data['Scr_d'].quantile(0.75)  # 3rd quartile (75th percentile)

# Create the histogram of 'Scr_d'
plt.figure(figsize=(10, 6))
sns.histplot(data['Scr_d'], bins=30, kde=True, color='purple', label='Scr_d')

# Add vertical lines for the quartiles
plt.axvline(q1, color='orange', linestyle='--', label=f'Q1 (25th percentile): {q1:.2f}')
plt.axvline(median_scr_d, color='black', linestyle='--', label=f'Median (50th percentile): {median_scr_d:.2f}')
plt.axvline(q3, color='red', linestyle='--', label=f'Q3 (75th percentile): {q3:.2f}')

# Adding titles and labels
plt.title('Histogram of Screen Diagonal (Scr_d)', fontsize=16)
plt.xlabel('Length of Screen Diagonal (Scr_d)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# The children want phones that have very good screen sizes
# Consider the phones that have screen sizes greater than or equal to the upper quartile value in the data set
# Create a logical condition for this situation and store the logical values as "con3"

# Calculate the 3rd quartile (upper quartile) of the 'Scr_d' feature
q3 = data['Scr_d'].quantile(0.75)

# Create the logical condition for phones with screen sizes <= upper quartile
data['con3'] = data['Scr_d'] <= q3

# Display the first few rows to confirm the new column
print(data[['Scr_d', 'con3']].head())
# Out:
#    Scr_d  con3
# 0      3  True
# 1      2  True
# 2      2  True
# 3     15  True
# 4     12  True

# %% [markdown]
# Observations:
#
# The features "Scr_h" and "Scr_w" are respectively the height and the width of the phone screen.
#
# We created a new feature called "Scr_d" which is essentially the length of the screen diagonal.
#
# The upper quartile has been selected as a threshold in this case as the children were very particular on this point.
#
# In case it is too strict, we can choose the mean or the median as a threshold.

# %% [markdown]
# # Task 5 - Obtain the logical conditions for the features "PC" and "FC"

# %%
# Let's tackle these features: "PC", "FC"

# %%
# Create a histogram of the "PC" feature and also show the mean and the median

import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the mean and median of the 'PC' feature
mean_pc = data['PC'].mean()
median_pc = data['PC'].median()

# Create the histogram of 'PC'
plt.figure(figsize=(10, 6))
sns.histplot(data['PC'], bins=30, kde=True, color='darkgreen', label='PC')

# Add vertical lines for the mean and median
plt.axvline(mean_pc, color='red', linestyle='--', label=f'Mean: {mean_pc:.2f}')
plt.axvline(median_pc, color='black', linestyle='--', label=f'Median: {median_pc:.2f}')

# Adding titles and labels
plt.title('Histogram of the PC Feature', fontsize=16)
plt.xlabel('PC', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# Create a histogram of the "FC" feature and also show the mean and the median
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the mean and median of the 'FC' feature
mean_fc = data['FC'].mean()
median_fc = data['FC'].median()

# Create the histogram of 'FC'
plt.figure(figsize=(10, 6))
sns.histplot(data['FC'], bins=30, kde=True, color='purple', label='FC')

# Add vertical lines for the mean and median
plt.axvline(mean_pc, color='darkblue', linestyle='--', label=f'Mean: {mean_fc:.2f}')
plt.axvline(median_pc, color='orange', linestyle='--', label=f'Median: {median_fc:.2f}')

# Adding titles and labels
plt.title('Histogram of the FC Feature', fontsize=16)
plt.xlabel('FC', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# The children want phones that have good primary and front camera resolutions
# Consider the phones that have primary and front camera resolutions greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con4"

# Calculate the mean values for the 'Primary_Camera' and 'Front_Camera' features
mean_primary_camera = data['PC'].mean()
mean_front_camera = data['FC'].mean()

# Create the logical condition for phones where both camera resolutions are >= their respective means
data['con4'] = (data['PC'] >= mean_primary_camera) & (data['FC'] >= mean_front_camera)

# Display the first few rows to confirm the new column
print(data[['PC', 'FC', 'con4']].head())
# Out:
#    PC  FC   con4
# 0   2   2  False
# 1   4   2  False
# 2   4   2  False
# 3   6   2  False
# 4   6   2  False

# %% [markdown]
# Observations:
#
# The features "PC" and "FC" are respectively the resolutions of the primary camera and the front camera.
#
# The respective means have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective medians as thresholds.

# %% [markdown]
# # Task 6 - Obtain the logical conditions for the features "Int_Mem", "Bty_Pwr" and "RAM"

# %%
# Let's tackle these features: "Int_Mem", "Bty_Pwr", "RAM"

# %%
# Create a histogram of the "Int_Mem" feature and also show the mean and the median
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the mean and median of the 'Int_Mem' feature
mean_Int_Mem = data['Int_Mem'].mean()
median_Int_Mem = data['Int_Mem'].median()

# Create the histogram of 'Int_Mem'
plt.figure(figsize=(10, 6))
sns.histplot(data['Int_Mem'], bins=30, kde=True, color='green', label='Int_Mem')

# Add vertical lines for the mean and median
plt.axvline(mean_pc, color='purple', linestyle='--', label=f'Mean: {mean_Int_Mem:.2f}')
plt.axvline(median_pc, color='grey', linestyle='--', label=f'Median: {median_Int_Mem:.2f}')

# Adding titles and labels
plt.title('Histogram of the Int_Mem Feature', fontsize=16)
plt.xlabel('Int_Mem', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# Create a histogram of the "Bty_Pwr" feature and also show the mean and the median
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the mean and median of the 'Bty_Pwr' feature
mean_Bty_Pwr = data['Bty_Pwr'].mean()
median_Bty_Pwr = data['Bty_Pwr'].median()

# Create the histogram of 'Bty_Pwr'
plt.figure(figsize=(10, 6))
sns.histplot(data['Bty_Pwr'], bins=30, kde=True, color='yellow', label='Bty_Pwr')

# Add vertical lines for the mean and median
plt.axvline(mean_pc, color='blue', linestyle='--', label=f'Mean: {mean_Bty_Pwr:.2f}')
plt.axvline(median_pc, color='red', linestyle='--', label=f'Median: {median_Bty_Pwr:.2f}')

# Adding titles and labels
plt.title('Histogram of the Bty_Pwr Feature', fontsize=16)
plt.xlabel('Bty_Pwr', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# Create a histogram of the "RAM" feature and also show the mean and the median
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the mean and median of the 'PC' feature
mean_RAM = data['RAM'].mean()
median_RAM = data['RAM'].median()

# Create the histogram of 'PC'
plt.figure(figsize=(10, 6))
sns.histplot(data['RAM'], bins=30, kde=True, color='pink', label='RAM')

# Add vertical lines for the mean and median
plt.axvline(mean_pc, color='purple', linestyle='--', label=f'Mean: {mean_RAM:.2f}')
plt.axvline(median_pc, color='skyblue', linestyle='--', label=f'Median: {median_RAM:.2f}')

# Adding titles and labels
plt.title('Histogram of the RAM Feature', fontsize=16)
plt.xlabel('RAM', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# The children want phones that have good internal memory, battery power and RAM
# Consider the phones that have internal memory, battery power and RAM greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con5"
# Calculate the mean values for the 'internal memory, battery power and RAM' features
mean_internal_memory = data['Int_Mem'].mean()
mean_battery_power = data['Bty_Pwr'].mean()
mean_RAM = data['RAM'].mean()


# Create the logical condition for phones phones that have internal memory, battery power and RAM are >= their respective means
data['con5'] = (data['PC'] >= mean_primary_camera) & (data['FC'] >= mean_front_camera)

# Display the first few rows to confirm the new column
print(data[['Int_Mem', 'Bty_Pwr','RAM', 'con5']].head())
# Out:
#    Int_Mem  Bty_Pwr  RAM   con5
# 0        8     2800    2  False
# 1        8     3000    2  False
# 2        8     3300    2  False
# 3       32     3000    2  False
# 4       16     3000    2  False

# %% [markdown]
# Observations
#
# The features "Int_Mem", "Bty_Pwr" and "RAM" are respectively the internal memory, battery power and RAM of the phones.
#
# The respective means have been selected as thresholds in this case.
#
# .In case it is too strict, we can choose the respective medians as thresholds

# %% [markdown]
# # Task 7 - Obtain the logical conditions for the features "Depth" and "Weight"

# %%
# Let's tackle these features: "Depth", "Weight"

# %%
# Create a histogram of the "Depth" feature and also show the mean and the median
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the mean and median of the 'Depth' feature
mean_Depth = data['Depth'].mean()
median_Depth = data['Depth'].median()

# Create the histogram of 'Depth'
plt.figure(figsize=(10, 6))
sns.histplot(data['Depth'], bins=30, kde=True, color='pink', label='Depth')

# Add vertical lines for the mean and median
plt.axvline(mean_Depth, color='purple', linestyle='--', label=f'Mean: {mean_Depth:.2f}')
plt.axvline(median_Depth, color='skyblue', linestyle='--', label=f'Median: {median_Depth:.2f}')

# Adding titles and labels
plt.title('Histogram of the Depth Feature', fontsize=16)
plt.xlabel('Depth', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# Create a histogram of the "Weight" feature and also show the mean and the median
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the mean and median of the 'Weight' feature
mean_Weight = data['Weight'].mean()
median_Weight = data['Weight'].median()
# Create the histogram of 'Weight'
plt.figure(figsize=(10, 6))
sns.histplot(data['Weight'], bins=30, kde=True, color='pink', label='Weight')

# Add vertical lines for the mean and median
plt.axvline(mean_Weight, color='purple', linestyle='--', label=f'Mean: {mean_Weight:.2f}')
plt.axvline(median_Weight, color='skyblue', linestyle='--', label=f'Median: {median_Weight:.2f}')

# Adding titles and labels
plt.title('Histogram of the Weight Feature', fontsize=16)
plt.xlabel('Weight', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# The children want phones that are light weight and slim
# Consider the phones that have depth and weight less than or equal to the respective median values in the data set
# Create a logical condition for this situation and store the logical values as "con6"

# Calculate the mean values for the 'depth and weight' features
mean_Depth = data['Depth'].mean()
mean_Weight = data['Weight'].mean()



# Create the logical condition for phones phones that have epth and weight are <= their respective means
data['con6'] = (data['Depth'] <= mean_Depth) & (data['Weight']<= mean_Weight)

# Display the first few rows to confirm the new column
print(data[['Depth', 'Weight','con6']].head())
# Out:
#    Depth  Weight   con6
# 0      7     320  False
# 1      7     280  False
# 2      7     400  False
# 3      3     300  False
# 4      3     210  False

# %% [markdown]
# Observations:
#
# The features "Depth" and "Weight" are respectively the depth of the phone and the weight of the phone.
#
# The respective medians have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective means as thresholds.

# %% [markdown]
# # Task 8 - Subset the data based on all the logical conditions

# %%
# Subset the dataframe using all the logical conditions that have been stored
# Store the subset of the dataframe as a new dataframe called "df1"
df1 = data[(data['con2']) & (data['con3']) & (data['con4'])& (data['con5'])& (data['con6'])]

# Display the first few rows of the new dataframe
print(df1.head())
# Out:
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  ...  \
# 9   ENG897N  yes   yes     yes     yes  2580  1980      5      3  64  ...
# 16  PDF768G   no    no     yes     yes  2580  1980      8      6  64  ...
# 21  QWR222Y   no   yes     yes     yes  2580  1980      8      6  64  ...
# 30  TVF078Y  yes   yes     yes     yes  2580  2120      8      6  64  ...
# 32  TYS938L  yes   yes     yes     yes  2580  2120      8      6  64  ...
#
#     Depth  Weight  Price       Px  con2  Scr_d  con3  con4  con5  con6
# 9       3     150  23456  5108400  True     15  True  True  True  True
# 16      3     160  22650  5108400  True     48  True  True  True  True
# 21      3     160  21350  5108400  True     48  True  True  True  True
# 30      3      90  29999  5469600  True     48  True  True  True  True
# 32      3     120  46777  5469600  True     48  True  True  True  True
#
# [5 rows x 24 columns]

# %%
# Get the dimensions of the dataframe
df1.shape
# Out:
# (10, 24)

# %%
# Sort the dataframe according to the "Price" feature in ascending order and display it

df1_sorted = df1.sort_values(by='Price', ascending=True)

# Display the sorted dataframe
print(df1_sorted.head())
# Out:
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  ...  \
# 21  QWR222Y   no   yes     yes     yes  2580  1980      8      6  64  ...
# 16  PDF768G   no    no     yes     yes  2580  1980      8      6  64  ...
# 9   ENG897N  yes   yes     yes     yes  2580  1980      5      3  64  ...
# 30  TVF078Y  yes   yes     yes     yes  2580  2120      8      6  64  ...
# 42  WZB298K  yes   yes     yes     yes  2580  1980      8      6  64  ...
#
#     Depth  Weight  Price       Px  con2  Scr_d  con3  con4  con5  con6
# 21      3     160  21350  5108400  True     48  True  True  True  True
# 16      3     160  22650  5108400  True     48  True  True  True  True
# 9       3     150  23456  5108400  True     15  True  True  True  True
# 30      3      90  29999  5469600  True     48  True  True  True  True
# 42      3     160  39000  5108400  True     48  True  True  True  True
#
# [5 rows x 24 columns]

# %% [markdown]
# Observations:
#
# Based on all the logical conditions obtained through analysis of the features, we are left with three phones.
#
# The most expensive of these phones is the "TYS938L" model and the least expensive is the "TVF078Y" model.
#
# We could let the children choose from these three phones as per their preferences.

# %% [markdown]
# # Task 9 - Study the variability of the features in the original data set

# %%
# Calculate the ratio of the standard deviation to the mean for all the numerical features in the dataframe
# Store these values in a new series wherein the rows are the features and the only column is the calculated ratio
# Name the series as "deviations"

import math
# Calculate the mean and standard deviation for all numerical columns
numerical_features = df1.select_dtypes(include=np.number).columns
mean_values = df1[numerical_features].mean() # Calculate mean only for numerical features
std_values = df1[numerical_features].std()  # Calculate std only for numerical features

# Calculate the ratio of standard deviation to mean for each numerical feature
ratio_std_to_mean = std_values / mean_values

# Display the ratio for all numerical features
print(ratio_std_to_mean)
# Out:
# Px_h       0.054275
# Px_w       0.109788
# Scr_h      0.123206
# Scr_w      0.166436
# PC         0.351364
# FC         0.351364
# Int_Mem    0.788138
# Bty_Pwr    0.213399
# RAM        0.408248
# Depth      0.178906
# Weight     0.229403
# Price      0.742136
# Px         0.166544
# Scr_d      0.233457
# dtype: float64

# %%
# Calculate the ratio of standard deviation to mean for each numerical feature
ratio_std_to_mean = std_values / mean_values

# Convert the ratio to a new DataFrame where the rows are the feature names and the column is 'Ratio'
df1_ratio = ratio_std_to_mean.to_frame(name='Ratio')

# Display the new DataFrame
print(df1_ratio)
# Out:
#             Ratio
# Px_h     0.054275
# Px_w     0.109788
# Scr_h    0.123206
# Scr_w    0.166436
# PC       0.351364
# FC       0.351364
# Int_Mem  0.788138
# Bty_Pwr  0.213399
# RAM      0.408248
# Depth    0.178906
# Weight   0.229403
# Price    0.742136
# Px       0.166544
# Scr_d    0.233457

# %%
deviations = std_values / mean_values

# Convert the series to a DataFrame with the name 'deviations'
df_deviations = deviations.to_frame(name='Deviations')

# Display the new DataFrame
print(df_deviations)
# Out:
#          Deviations
# Px_h       0.054275
# Px_w       0.109788
# Scr_h      0.123206
# Scr_w      0.166436
# PC         0.351364
# FC         0.351364
# Int_Mem    0.788138
# Bty_Pwr    0.213399
# RAM        0.408248
# Depth      0.178906
# Weight     0.229403
# Price      0.742136
# Px         0.166544
# Scr_d      0.233457

# %%
# View the "deviations" series after sorting it in descending order
deviations_sorted = deviations.sort_values(ascending=False)

# Display the sorted series
print(deviations_sorted)
# Out:
# Int_Mem    0.788138
# Price      0.742136
# RAM        0.408248
# PC         0.351364
# FC         0.351364
# Scr_d      0.233457
# Weight     0.229403
# Bty_Pwr    0.213399
# Depth      0.178906
# Px         0.166544
# Scr_w      0.166436
# Scr_h      0.123206
# Px_w       0.109788
# Px_h       0.054275
# dtype: float64

# %% [markdown]
# Observations:
#
# The ratio of the standard deviation to the mean of a feature normalises it in a way.
#
# This allows for comparison between multiple features.
#
# The most variable feature in the original data set is the internal memory of the phones.
#
# The least variable feature in the original data set is the number of screen pixels in the horizontal axis.
#
# Although most features don't seem so variable, the prices of the phones are quite variable.
#
# Feel free to investigate what could be the cause of this difference in variability.
#
# Note: We encourage you to extend this analysis further and see what else you can find.
#
# Note: Please refer to the official website of Python and its libraries for various Python documentations.

# %% [markdown]
# # Conclusion
# 1. We have used concepts of descriptive statistics to study and work with a data set that contains mobile phone specifications.
#
# 2. We were able to recommend three phone models to the client which she can then propose to her children.
